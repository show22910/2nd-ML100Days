# %%
target_url ='https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt'

# %%
import requests
response = requests.get(target_url)
data = response.text

# 用 request 傳送回來的資料不會認得斷行符號
print(len(data))
data[0:100]
# Out:
# 784594
# 'n00015388_157\thttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg\nn00015388_238\thttp://farm2'

# %%
split_tag = '\n'

data = data.split(split_tag)
print(len(data))
data[0]
# Out:
# 9996
# 'n00015388_157\thttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg'

# %%
import pandas as pd
arrange_data=[]
for i in data:
    i=i.replace('\t', ' ')
    arrange_data.append(i)
    
df = pd.DataFrame(arrange_data)
df.head()
# Out:
#                                                    0
# 0  n00015388_157 http://farm1.static.flickr.com/1...
# 1  n00015388_238 http://farm2.static.flickr.com/1...
# 2  n00015388_304 http://farm1.static.flickr.com/2...
# 3  n00015388_327 http://farm4.static.flickr.com/3...
# 4  n00015388_355 http://img100.imageshack.us/img1...

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

df
# 請用 df.loc[...] 得到第一筆資料的連結
#first_link = df.loc[0, 'Photo link']

#response = requests.get(first_link)
#img = Image.open(BytesIO(response.content))

# Convert img to numpy array

#plt.imshow(img)
#plt.show()
# Out:
#                                                       0
# 0     n00015388_157 http://farm1.static.flickr.com/1...
# 1     n00015388_238 http://farm2.static.flickr.com/1...
# 2     n00015388_304 http://farm1.static.flickr.com/2...
# 3     n00015388_327 http://farm4.static.flickr.com/3...
# 4     n00015388_355 http://img100.imageshack.us/img1...
# 5     n00015388_373 http://img172.imageshack.us/img1...
# 6     n00015388_379 http://fotootjesvanannelies.web-...
# 7     n00015388_388 http://www.deweekkrant.nl/images...
# 8     n00015388_442 http://www.porschemania.it/discu...
# 9     n00015388_474 http://farm1.static.flickr.com/7...
# 10    n00015388_514 http://farm2.static.flickr.com/1...
# 11    n00015388_671 http://farm4.static.flickr.com/3...
# 12    n00015388_686 http://farm1.static.flickr.com/2...
# 13    n00015388_706 http://www.dierentuin.nl/images/...
# 14    n00015388_725 http://farm4.static.flickr.com/3...
# 15    n00015388_758 https://w3f7yg.bay.livefilestore...
# 16    n00015388_841 http://farm4.static.flickr.com/3...
# 17    n00015388_842 http://farm2.static.flickr.com/1...
# 18    n00015388_1087 http://farm1.static.flickr.com/...
